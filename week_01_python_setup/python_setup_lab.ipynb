# %% [markdown]
# # Week 1 - Python Setup Lab
#
# Use this notebook during the first session before or after running `profile_app.py`.

# %% [markdown]
# ## Mental model
#
# A Python program is a list of instructions. Python runs them from top to bottom.

# %%
name = 'Alex'
age = 25

print(name)
print(age)

# %% [markdown]
# ## Strings and numbers
#
# `input()` always gives text. If we want math, we convert the text to a number.

# %%
age_text = '25'
age_number = int(age_text)

print(age_text + '5')
print(age_number + 5)

# %% [markdown]
# ## Build a profile message

# %%
name = 'Maria'
city = 'Athens'
favorite_language = 'Python'

message = f'{name} lives in {city} and is learning {favorite_language}.'
print(message)

# %% [markdown]
# ## Exercise
#
# Change the values above, then add three new variables:
#
# - favorite movie
# - favorite car
# - fun fact
